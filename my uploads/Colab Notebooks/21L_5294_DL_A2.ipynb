# %% [markdown]
# # Question 1

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Activation, MaxPooling2D, Dense, Flatten,  BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import SGD, RMSprop, Adam
from sklearn.metrics import confusion_matrix
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
def build_cnn_model(input_shape=(32, 32, 3),num_filters=[128,128,128,128,128],filter_sizes=[(3, 3)]*5,activations=['relu']*5,pool_size=(2, 2),dense_neurons=1024,num_classes=10):

    model = Sequential()

    # Add 5 conv-relu-maxpool blocks
    for i in range(5):
        if i == 0:
            # First layer needs input_shape
            model.add(Conv2D(num_filters[i], filter_sizes[i], input_shape=input_shape, padding='same'))
        else:
            model.add(Conv2D(num_filters[i], filter_sizes[i], padding='same'))
        model.add(Activation(activations[i]))
        model.add(MaxPooling2D(pool_size=pool_size))

    # Flatten the output for dense layers
    model.add(Flatten())

    # Dense layer
    model.add(Dense(dense_neurons, activation='relu'))

    # Output layer
    model.add(Dense(num_classes, activation='softmax'))

    return model

# %%
# Normalize pixel values to [0, 1]
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Convert labels to one-hot encoding
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Build the model
model = build_cnn_model()

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_55 (Conv2D)              │ (None, 32, 32, 128)    │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_62 (Activation)      │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_55 (MaxPooling2D) │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_56 (Conv2D)              │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_63 (Activation)      │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_56 (MaxPooling2D) │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_57 (Conv2D)              │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_64 (Activation)      │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_57 (MaxPooling2D) │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_58 (Conv2D)              │ (None, 4, 4, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_65 (Activation)      │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_58 (MaxPooling2D) │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_59 (Conv2D)              │ (None, 2, 2, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_66 (Activation)      │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_59 (MaxPooling2D) │ (None, 1, 1, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_11 (Flatten)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 1024)           │       132,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 10)             │        10,250 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 736,266 (2.81 MB)
#  Trainable params: 736,266 (2.81 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Define early stopping callback
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

# Train the model with early stopping
history = model.fit(x_train, y_train,
                    batch_size=128,
                    epochs=100,  # Set high to allow early stopping to control
                    validation_split=0.2,
                    callbacks=[early_stopping],
                    verbose=1)
# Out:
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.2637 - loss: 1.9436 - val_accuracy: 0.4926 - val_loss: 1.3892
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.5394 - loss: 1.2573 - val_accuracy: 0.6005 - val_loss: 1.1358
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.6403 - loss: 1.0078 - val_accuracy: 0.6728 - val_loss: 0.9407
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.7097 - loss: 0.8306 - val_accuracy: 0.6904 - val_loss: 0.8857
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.7551 - loss: 0.6931 - val_accuracy: 0.7268 - val_loss: 0.8054
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.7972 - loss: 0.5791 - val_accuracy: 0.7143 - val_loss: 0.8440
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8217 - loss: 0.5064 - val_accuracy: 0.7391 - val_loss: 0.8185
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8499 - loss: 0.4188 - val_accuracy: 0.7281 - val_loss: 0.8515
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8719 - loss: 0.3620 - val_accuracy: 0.7309 - val_loss: 0.8984
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8989 - loss: 0.2873 - val_accuracy: 0.7380 - val_loss: 0.9670
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9163 - loss: 0.2331 - val_accuracy: 0.7380 - val_loss: 0.9419
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9275 - loss: 0.2038 - val_accuracy: 0.7345 - val_loss: 1.0754
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9380 - loss: 0.1721 - val_accuracy: 0.7255 - val_loss: 1.0693
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9494 - loss: 0.1414 - val_accuracy: 0.7265 - val_loss: 1.2797
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9482 - loss: 0.1505 - val_accuracy: 0.7332 - val_loss: 1.2721
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9559 - loss: 0.1276 - val_accuracy: 0.7302 - val_loss: 1.3930
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9626 - loss: 0.1049 - val_accuracy: 0.7326 - val_loss: 1.3684
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9700 - loss: 0.0874 - val_accuracy: 0.7356 - val_loss: 1.3948
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9673 - loss: 0.0936 - val_accuracy: 0.7361 - val_loss: 1.4586
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9675 - loss: 0.0914 - val_accuracy: 0.7375 - val_loss: 1.3696
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9714 - loss: 0.0832 - val_accuracy: 0.7229 - val_loss: 1.6316
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9721 - loss: 0.0802 - val_accuracy: 0.7322 - val_loss: 1.5215
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 7.

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f'\nTest Accuracy: {test_accuracy:.4f}, Test Loss: {test_loss:.4f}')
# Out:
# Test Accuracy: 0.7325, Test Loss: 0.8260

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy', marker='o')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', marker='s')
plt.title('Training and Validation Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.savefig('accuracy_plot.png')

# %% [markdown]
# # Question 2

# %%
# Define optimizers
optimizers = [
    ('SGD', SGD(learning_rate=0.01, momentum=0.9)),
    ('RMSprop', RMSprop(learning_rate=0.001)),
    ('Adam', Adam(learning_rate=0.001))
]

# %%
results = []

for opt_name, optimizer in optimizers:
  print(f"\nTraining with optimizer: {opt_name}")

  model = build_cnn_model()

  model.compile(
      optimizer=optimizer,
      loss='categorical_crossentropy',
      metrics=['accuracy']
  )
  early_stopping = EarlyStopping(
  monitor='val_accuracy',
  patience=15,
  restore_best_weights=True,
  verbose=1)


  history = model.fit(
      x_train, y_train,
      batch_size=128,
      epochs=100,
      validation_split=0.2,
      callbacks=[early_stopping],
      verbose=1
  )


  test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
  print(f"Test Accuracy: {test_accuracy:.4f}, Test Loss: {test_loss:.4f}")

  model.save(f'cifar10_model_{opt_name}.keras')


  results.append({
      'Optimizer': opt_name,
      'Test Accuracy': test_accuracy,
      'Test Loss': test_loss,
      'History': history.history
  })

results_df = pd.DataFrame({
    'Optimizer': [r['Optimizer'] for r in results],
    'Test Accuracy': [r['Test Accuracy'] for r in results],
    'Test Loss': [r['Test Loss'] for r in results]
})

results_df.to_csv('optimizer_results.csv')
# Out:
# Training with optimizer: SGD
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.1492 - loss: 2.2444 - val_accuracy: 0.3191 - val_loss: 1.8909
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.3389 - loss: 1.7963 - val_accuracy: 0.4396 - val_loss: 1.5262
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.4573 - loss: 1.4836 - val_accuracy: 0.5242 - val_loss: 1.3078
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.5332 - loss: 1.2896 - val_accuracy: 0.5690 - val_loss: 1.2171
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.5829 - loss: 1.1626 - val_accuracy: 0.5917 - val_loss: 1.1500
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.6398 - loss: 1.0145 - val_accuracy: 0.6230 - val_loss: 1.0615
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.6818 - loss: 0.8967 - val_accuracy: 0.6841 - val_loss: 0.9035
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.7128 - loss: 0.8027 - val_accuracy: 0.6909 - val_loss: 0.8965
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.7490 - loss: 0.7080 - val_accuracy: 0.6991 - val_loss: 0.8810
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.7727 - loss: 0.6446 - val_accuracy: 0.7071 - val_loss: 0.8561
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8101 - loss: 0.5372 - val_accuracy: 0.7164 - val_loss: 0.8551
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8306 - loss: 0.4759 - val_accuracy: 0.7081 - val_loss: 0.9116
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8582 - loss: 0.4112 - val_accuracy: 0.7174 - val_loss: 0.8853
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.8777 - loss: 0.3429 - val_accuracy: 0.7049 - val_loss: 1.0294
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8918 - loss: 0.3044 - val_accuracy: 0.7207 - val_loss: 0.9954
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9056 - loss: 0.2664 - val_accuracy: 0.7167 - val_loss: 1.0479
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9188 - loss: 0.2328 - val_accuracy: 0.7100 - val_loss: 1.1217
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9311 - loss: 0.1955 - val_accuracy: 0.7297 - val_loss: 1.1268
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9445 - loss: 0.1579 - val_accuracy: 0.7250 - val_loss: 1.1888
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9525 - loss: 0.1342 - val_accuracy: 0.7084 - val_loss: 1.3688
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9526 - loss: 0.1365 - val_accuracy: 0.7290 - val_loss: 1.2681
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9549 - loss: 0.1266 - val_accuracy: 0.7253 - val_loss: 1.3456
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9642 - loss: 0.1040 - val_accuracy: 0.7260 - val_loss: 1.4059
# Epoch 24/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9712 - loss: 0.0825 - val_accuracy: 0.7256 - val_loss: 1.4770
# Epoch 25/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9667 - loss: 0.0954 - val_accuracy: 0.7267 - val_loss: 1.5019
# Epoch 26/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9759 - loss: 0.0697 - val_accuracy: 0.7137 - val_loss: 1.5463
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9668 - loss: 0.0940 - val_accuracy: 0.7256 - val_loss: 1.6055
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9769 - loss: 0.0673 - val_accuracy: 0.7169 - val_loss: 1.6541
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9734 - loss: 0.0778 - val_accuracy: 0.7116 - val_loss: 1.8464
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9755 - loss: 0.0720 - val_accuracy: 0.7233 - val_loss: 1.7057
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.
# Epoch 37/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9803 - loss: 0.0678 - val_accuracy: 0.7256 - val_loss: 2.4247
# Epoch 38/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9780 - loss: 0.0718 - val_accuracy: 0.7465 - val_loss: 2.0968
# Epoch 39/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9813 - loss: 0.0670 - val_accuracy: 0.7335 - val_loss: 2.1986
# Epoch 40/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9782 - loss: 0.0720 - val_accuracy: 0.7365 - val_loss: 2.2393
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 25.
# Test Accuracy: 0.7319, Test Loss: 1.8879
#
# Training with optimizer: Adam
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.2677 - loss: 1.9263 - val_accuracy: 0.4956 - val_loss: 1.3733
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.5316 - loss: 1.2619 - val_accuracy: 0.6287 - val_loss: 1.0425
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.6480 - loss: 0.9747 - val_accuracy: 0.6603 - val_loss: 0.9736
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.7071 - loss: 0.8258 - val_accuracy: 0.7121 - val_loss: 0.8272
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.7566 - loss: 0.6888 - val_accuracy: 0.7157 - val_loss: 0.8296
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.7911 - loss: 0.5963 - val_accuracy: 0.7143 - val_loss: 0.8415
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8230 - loss: 0.5031 - val_accuracy: 0.7441 - val_loss: 0.7784
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8589 - loss: 0.4020 - val_accuracy: 0.7377 - val_loss: 0.8287
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.8829 - loss: 0.3387 - val_accuracy: 0.7304 - val_loss: 0.8934
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8982 - loss: 0.2866 - val_accuracy: 0.7404 - val_loss: 0.9162
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9182 - loss: 0.2291 - val_accuracy: 0.7400 - val_loss: 0.9796
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9298 - loss: 0.1985 - val_accuracy: 0.7350 - val_loss: 1.0857
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9357 - loss: 0.1802 - val_accuracy: 0.7425 - val_loss: 0.9905
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9481 - loss: 0.1489 - val_accuracy: 0.7372 - val_loss: 1.1228
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9593 - loss: 0.1208 - val_accuracy: 0.7314 - val_loss: 1.2046
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9521 - loss: 0.1369 - val_accuracy: 0.7355 - val_loss: 1.2118
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9631 - loss: 0.1050 - val_accuracy: 0.7344 - val_loss: 1.2774
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9635 - loss: 0.1034 - val_accuracy: 0.7262 - val_loss: 1.2645
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9728 - loss: 0.0816 - val_accuracy: 0.7404 - val_loss: 1.4692
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9672 - loss: 0.0947 - val_accuracy: 0.7382 - val_loss: 1.3447
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9717 - loss: 0.0795 - val_accuracy: 0.7322 - val_loss: 1.3930
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9765 - loss: 0.0705 - val_accuracy: 0.7332 - val_loss: 1.5656
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 7.
# Test Accuracy: 0.7343, Test Loss: 0.8003

# %%
plt.figure(figsize=(15, 5))  # Adjusted for 1x3 layout
for i, result in enumerate(results):
    plt.subplot(1, 3, i + 1)  # 1 row, 3 columns
    plt.plot(result['History']['accuracy'], label='Train Accuracy', marker='o')
    plt.plot(result['History']['val_accuracy'], label='Val Accuracy', marker='s')
    plt.title(f'{result["Optimizer"]}')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.grid(True)
    plt.legend()
plt.tight_layout()
plt.savefig('optimizers_training_history.png')

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer','dog', 'frog', 'horse', 'ship', 'truck']

# %%
best_result = max(results, key=lambda x: x['Test Accuracy'])
best_opt_name = best_result['Optimizer']
best_model = tf.keras.models.load_model(f'cifar10_model_{best_opt_name}.keras')
y_pred = best_model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)
cm = confusion_matrix(y_true, y_pred_classes)


plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title(f'Confusion Matrix ({best_opt_name})')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.savefig('confusion_matrix_best.png')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %% [markdown]
# ## Question 3

# %%
def build_cnn_model(
    input_shape=(32, 32, 3),
    num_filters=[128]*5,  # m = 128 filters in each layer
    filter_sizes=[(3, 3)]*5,  # k = 3 (3x3 filters)
    activations=['relu']*5,
    pool_size=(2, 2),
    dense_neurons=1024,  # n = 1024 neurons in dense layer
    num_classes=10,
    use_batch_norm=False
):
    model = Sequential()
    for i in range(5):
        if i == 0:
            model.add(Conv2D(num_filters[i], filter_sizes[i], input_shape=input_shape, padding='same'))
        else:
            model.add(Conv2D(num_filters[i], filter_sizes[i], padding='same'))
        if use_batch_norm:
            model.add(BatchNormalization())
        model.add(Activation(activations[i]))
        model.add(MaxPooling2D(pool_size=pool_size))
    model.add(Flatten())
    model.add(Activation('relu'))
    if use_batch_norm:
        model.add(BatchNormalization())
    model.add(Dense(dense_neurons))
    model.add(Dense(num_classes, activation='softmax'))
    return model

# %%
configs = [
    {'name': 'Without BatchNorm', 'use_batch_norm': False},
    {'name': 'With BatchNorm', 'use_batch_norm': True}
]

# %%
# Store results
results = []

# Train and evaluate model for each configuration
for config in configs:
    print(f"\n=== Training {config['name']} ===")

    # Build model
    model = build_cnn_model(use_batch_norm=config['use_batch_norm'])

    # Compile model
    if config['use_batch_norm']:
      model.compile(optimizer=Adam(learning_rate=0.01),
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])
    else:
      model.compile(optimizer=Adam(learning_rate=0.001),
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])


    # Print model summary
    model.summary()

    # Define early stopping
    early_stopping = EarlyStopping(
        monitor='val_accuracy',
        patience=15,
        restore_best_weights=True,
        verbose=1
    )

    # Train model
    history = model.fit(x_train, y_train,
                        batch_size=128,
                        epochs=100,
                        validation_split=0.2,
                        callbacks=[early_stopping],
                        verbose=1)

    # Evaluate model
    test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
    print(f"\n{config['name']} Test Accuracy: {test_accuracy:.4f}, Test Loss: {test_loss:.4f}\n")

    # Store history and config
    results.append({
        'Name': config['name'],
        'History': history.history,
        'Test_Accuracy': test_accuracy,
        'Test_Loss': test_loss
    })
# Out:
# === Training Without BatchNorm ===
# Model: "sequential_16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_80 (Conv2D)              │ (None, 32, 32, 128)    │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_88 (Activation)      │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_80 (MaxPooling2D) │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_81 (Conv2D)              │ (None, 16, 16, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_89 (Activation)      │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_81 (MaxPooling2D) │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_82 (Conv2D)              │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_90 (Activation)      │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_82 (MaxPooling2D) │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_83 (Conv2D)              │ (None, 4, 4, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_91 (Activation)      │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_83 (MaxPooling2D) │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_84 (Conv2D)              │ (None, 2, 2, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_92 (Activation)      │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_84 (MaxPooling2D) │ (None, 1, 1, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_16 (Flatten)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_93 (Activation)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_32 (Dense)                │ (None, 1024)           │       132,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_33 (Dense)                │ (None, 10)             │        10,250 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 736,266 (2.81 MB)
#  Trainable params: 736,266 (2.81 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.2883 - loss: 1.8763 - val_accuracy: 0.5365 - val_loss: 1.2880
# Epoch 2/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.5595 - loss: 1.2171 - val_accuracy: 0.6426 - val_loss: 1.0056
# Epoch 3/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.6695 - loss: 0.9310 - val_accuracy: 0.6808 - val_loss: 0.9311
# Epoch 4/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.7310 - loss: 0.7693 - val_accuracy: 0.7090 - val_loss: 0.8218
# Epoch 5/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.7735 - loss: 0.6503 - val_accuracy: 0.7242 - val_loss: 0.7873
# Epoch 6/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8049 - loss: 0.5538 - val_accuracy: 0.7159 - val_loss: 0.8430
# Epoch 7/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8308 - loss: 0.4793 - val_accuracy: 0.7315 - val_loss: 0.8074
# Epoch 8/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8584 - loss: 0.4017 - val_accuracy: 0.7383 - val_loss: 0.8201
# Epoch 9/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8855 - loss: 0.3297 - val_accuracy: 0.7420 - val_loss: 0.8842
# Epoch 10/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9053 - loss: 0.2702 - val_accuracy: 0.7218 - val_loss: 1.0268
# Epoch 11/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9174 - loss: 0.2330 - val_accuracy: 0.7416 - val_loss: 1.0231
# Epoch 12/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9270 - loss: 0.2044 - val_accuracy: 0.7346 - val_loss: 1.1632
# Epoch 13/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9380 - loss: 0.1754 - val_accuracy: 0.7374 - val_loss: 1.0818
# Epoch 14/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9508 - loss: 0.1392 - val_accuracy: 0.7237 - val_loss: 1.2069
# Epoch 15/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9444 - loss: 0.1582 - val_accuracy: 0.7441 - val_loss: 1.2260
# Epoch 16/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9563 - loss: 0.1259 - val_accuracy: 0.7363 - val_loss: 1.2805
# Epoch 17/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9586 - loss: 0.1166 - val_accuracy: 0.7379 - val_loss: 1.4093
# Epoch 18/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9616 - loss: 0.1120 - val_accuracy: 0.7271 - val_loss: 1.4101
# Epoch 19/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9632 - loss: 0.1087 - val_accuracy: 0.7372 - val_loss: 1.4257
# Epoch 20/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9660 - loss: 0.0984 - val_accuracy: 0.7311 - val_loss: 1.4726
# Epoch 21/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9670 - loss: 0.0981 - val_accuracy: 0.7365 - val_loss: 1.4780
# Epoch 22/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9697 - loss: 0.0883 - val_accuracy: 0.7349 - val_loss: 1.5378
# Epoch 23/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.
# Epoch 27/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9820 - loss: 0.0551 - val_accuracy: 0.7549 - val_loss: 1.5181
# Epoch 28/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9784 - loss: 0.0643 - val_accuracy: 0.7120 - val_loss: 2.1018
# Epoch 29/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9682 - loss: 0.0975 - val_accuracy: 0.6683 - val_loss: 2.2957
# Epoch 30/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9757 - loss: 0.0746 - val_accuracy: 0.7640 - val_loss: 1.5088
# Epoch 31/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9864 - loss: 0.0398 - val_accuracy: 0.7528 - val_loss: 1.7586
# Epoch 32/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9812 - loss: 0.0565 - val_accuracy: 0.7332 - val_loss: 1.7506
# Epoch 33/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9853 - loss: 0.0450 - val_accuracy: 0.7540 - val_loss: 1.5555
# Epoch 34/100
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9805 - loss: 0.0605 - val_accuracy: 0.5843 - val_loss: 4.0077
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 19.
#
# With BatchNorm Test Accuracy: 0.7560, Test Loss: 1.3497

# %%
# Plot training and validation loss/accuracy in a single row
plt.figure(figsize=(12, 5))
for i, result in enumerate(results):
    # Accuracy subplot
    plt.subplot(1, 2, i + 1)
    plt.plot(result['History']['accuracy'], label='Train Accuracy', marker='o')
    plt.plot(result['History']['val_accuracy'], label='Val Accuracy', marker='s')
    plt.title(f"{result['Name']}")
    plt.xlabel('Epoch')
    plt.ylabel('Metric')
    plt.grid(True)
    plt.legend()
plt.tight_layout()
plt.savefig('batchnorm_comparison.png')

# %% [markdown]
# # Question 4

# %%
# Generate a more complex dataset with higher non-linearity and noise
np.random.seed(42)
n_samples = 1000
X1 = 2 * np.random.rand(n_samples, 1) - 1
X2 = 3 * np.random.rand(n_samples, 1) - 1.5
X3 = np.random.rand(n_samples, 1)
X = np.hstack([X1, X2, X3])

# Complex non-linear target: y = 2*x1^2 + 3*x2 + 0.5*x3 + sin(x1*x2) + 0.1*x1*x3^2 + noise
y = (2 * X1**2 + 3 * X2 + 0.5 * X3 + np.sin(X1 * X2) + 0.1 * X1 * X3**2 +
     0.2 * np.random.randn(n_samples, 1))

# Standardize features
X_mean = X.mean(axis=0)
X_std = X.std(axis=0)
X = (X - X_mean) / X_std
X_b = np.c_[np.ones((n_samples, 1)), X]

# %%
# Neural network model (1 hidden layer with ReLU)
def forward(X, theta1, theta2):
    hidden = np.maximum(0, X @ theta1)  # ReLU activation
    output = hidden @ theta2
    return output

def compute_loss(X, y, theta1, theta2):
    m = len(y)
    predictions = forward(X, theta1, theta2)
    errors = predictions - y
    return (1 / (2 * m)) * np.sum(errors ** 2)

def compute_gradients(X, y, theta1, theta2):
    m = len(y)
    hidden = np.maximum(0, X @ theta1)
    predictions = hidden @ theta2
    errors = predictions - y

    d_theta2 = (1 / m) * hidden.T @ errors
    d_hidden = errors @ theta2.T
    d_theta1 = (1 / m) * X.T @ (d_hidden * (hidden > 0))

    return d_theta1, d_theta2

# Gradient Descent Variants with learning rate scheduling
def gradient_descent(X, y, theta1_init, theta2_init, n_iterations):
    theta1, theta2 = theta1_init.copy(), theta2_init.copy()
    loss_history = []
    for i in range(n_iterations):
        lr = 0.01 / (1 + i / 1000)  # Learning rate decay
        d_theta1, d_theta2 = compute_gradients(X, y, theta1, theta2)
        theta1 -= lr * d_theta1
        theta2 -= lr * d_theta2
        loss = compute_loss(X, y, theta1, theta2)
        loss_history.append(loss)
    return theta1, theta2, loss_history

def stochastic_gradient_descent(X, y, theta1_init, theta2_init, n_iterations):
    theta1, theta2 = theta1_init.copy(), theta2_init.copy()
    loss_history = []
    m = len(y)
    for i in range(n_iterations):
        lr = 0.01 / (1 + i / 1000)
        for _ in range(m):
            idx = np.random.randint(m)
            xi = X[idx:idx+1]
            yi = y[idx:idx+1]
            d_theta1, d_theta2 = compute_gradients(xi, yi, theta1, theta2)
            theta1 -= lr * d_theta1
            theta2 -= lr * d_theta2
        loss = compute_loss(X, y, theta1, theta2)
        loss_history.append(loss)
    return theta1, theta2, loss_history

def mini_batch_gradient_descent(X, y, theta1_init, theta2_init, n_iterations, batch_size):
    theta1, theta2 = theta1_init.copy(), theta2_init.copy()
    loss_history = []
    m = len(y)
    for i in range(n_iterations):
        lr = 0.01 / (1 + i / 1000)
        indices = np.random.permutation(m)
        X_shuffled, y_shuffled = X[indices], y[indices]
        for j in range(0, m, batch_size):
            xi = X_shuffled[j:j+batch_size]
            yi = y_shuffled[j:j+batch_size]
            d_theta1, d_theta2 = compute_gradients(xi, yi, theta1, theta2)
            theta1 -= lr * d_theta1
            theta2 -= lr * d_theta2
        loss = compute_loss(X, y, theta1, theta2)
        loss_history.append(loss)
    return theta1, theta2, loss_history

# %%
# Parameters
input_size, hidden_size, output_size = 4, 10, 1
theta1_init = np.random.randn(input_size, hidden_size) * 0.01
theta2_init = np.random.randn(hidden_size, output_size) * 0.01
n_iterations = 1000
batch_size = 32

# %%
theta1_gd, theta2_gd, loss_gd = gradient_descent(X_b, y, theta1_init, theta2_init, n_iterations)
theta1_sgd, theta2_sgd, loss_sgd = stochastic_gradient_descent(X_b, y, theta1_init, theta2_init, n_iterations)
theta1_mbgd, theta2_mbgd, loss_mbgd = mini_batch_gradient_descent(X_b, y, theta1_init, theta2_init, n_iterations, batch_size)

# %%
# Plotting convergence
plt.figure(figsize=(10, 6))
plt.plot(loss_gd, label='Vanilla GD', color='blue')
plt.plot(loss_sgd, label='SGD', color='orange')
plt.plot(loss_mbgd, label='Mini-batch GD', color='green')
plt.xlabel('Iteration')
plt.ylabel('Loss (MSE)')
plt.title('Loss Convergence of Gradient Descent Variants (Complex Dataset)')
plt.legend()
plt.grid(True)
plt.yscale('log')  # Log scale to highlight differences
plt.savefig('loss_convergence_improved.png')

# %% [markdown]
# # Question 5

# %%
# !pip install keras_tuner
# Out:
# Collecting keras_tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.11/dist-packages (from keras_tuner) (3.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras_tuner) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from keras_tuner) (2.32.3)
# Collecting kt-legacy (from keras_tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (0.0.9)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (3.13.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (0.15.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras->keras_tuner) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->keras_tuner) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->keras_tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->keras_tuner) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->keras_tuner) (2025.4.26)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras->keras_tuner) (4.13.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras_tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras->keras_tuner) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras_tuner) (0.1.2)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 11.1 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras_tuner
# Successfully installed keras_tuner-1.4.7 kt-legacy-1.0.5

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Activation, MaxPooling2D, Dense, Flatten, BatchNormalization, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
import keras_tuner as kt
import matplotlib.pyplot as plt

# %%
# Define the model-building function for KerasTuner
def build_cnn_model(hp):
    model = Sequential()

    # Tune the number of convolutional layers (between 3 and 5)
    num_conv_layers = hp.Int('num_conv_layers', min_value=3, max_value=5, default=5)

    # Input shape for CIFAR-10
    input_shape = (32, 32, 3)

    # Add convolutional layers
    for i in range(num_conv_layers):
        # Tune the number of filters for each conv layer (between 32 and 256)
        num_filters = hp.Int(f'filters_{i}', min_value=32, max_value=256, step=32, default=128)
        filter_size = (3, 3)  # Fixed as per original model
        if i == 0:
            model.add(Conv2D(num_filters, filter_size, input_shape=input_shape, padding='same'))
        else:
            model.add(Conv2D(num_filters, filter_size, padding='same'))
        model.add(BatchNormalization())  # Keep BN as in corrected model
        model.add(Activation('relu'))
        # Add max pooling after every conv layer
        model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())

    # Tune the number of neurons in the dense layer (between 256 and 2048)
    dense_neurons = hp.Int('dense_neurons', min_value=256, max_value=2048, step=256, default=1024)
    model.add(Dense(dense_neurons))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    # Tune dropout rate (between 0.0 and 0.5)
    dropout_rate = hp.Float('dropout_rate', min_value=0.0, max_value=0.5, step=0.1, default=0.2)
    model.add(Dropout(dropout_rate))

    # Output layer for 10 classes
    model.add(Dense(10, activation='softmax'))

    # Tune the learning rate for Adam optimizer (between 1e-4 and 1e-2)
    learning_rate = hp.Float('learning_rate', min_value=1e-4, max_value=1e-2, sampling='log')
    model.compile(optimizer=Adam(learning_rate=learning_rate),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# %%
# Load and preprocess CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
# Normalize pixel values to [0, 1]
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Convert labels to one-hot encoding
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Define batch sizes to test
batch_sizes = [32, 64, 96, 128, 256]

# %%
# Store results for each batch size
results = []

# Define early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

# Tune hyperparameters for each batch size
best_val_accuracy = 0
best_batch_size = None
best_hps = None
best_history = None
best_model = None

for batch_size in batch_sizes:
    print(f"\n=== Tuning with Batch Size {batch_size} ===")

    # Define the tuner for this batch size
    tuner = kt.Hyperband(
        build_cnn_model,
        objective='val_accuracy',
        max_epochs=30,
        factor=3,
        hyperband_iterations=1,  # Reduced for faster tuning
        directory='kerastuner_dir',
        project_name=f'cifar10_tuning_batch_{batch_size}',
        overwrite=True
    )

    # Perform the hyperparameter search
    tuner.search(
        x_train, y_train,
        epochs=30,
        batch_size=batch_size,
        validation_split=0.2,
        callbacks=[early_stopping],
        verbose=1
    )

    # Get the best hyperparameters for this batch size
    batch_best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

    # Build the model with the best hyperparameters
    batch_best_model = tuner.hypermodel.build(batch_best_hps)

    # Train the model to get the history
    history = batch_best_model.fit(
        x_train, y_train,
        epochs=30,
        batch_size=batch_size,
        validation_split=0.2,
        callbacks=[early_stopping],
        verbose=1
    )

    # Evaluate the model on the test set
    test_loss, test_accuracy = batch_best_model.evaluate(x_test, y_test, verbose=0)

    # Store results
    results.append({
        'Batch Size': batch_size,
        'Best Hyperparameters': batch_best_hps,
        'Validation Accuracy': max(history.history['val_accuracy']),
        'Test Accuracy': test_accuracy,
        'Test Loss': test_loss,
        'History': history.history
    })

    # Update best overall
    if max(history.history['val_accuracy']) > best_val_accuracy:
        best_val_accuracy = max(history.history['val_accuracy'])
        best_batch_size = batch_size
        best_hps = batch_best_hps
        best_history = history.history
        best_model = batch_best_model

# Print the best overall hyperparameters
print("\n=== Best Overall Hyperparameters ===")
print(f"Best Batch Size: {best_batch_size}")
print(f"Number of Convolutional Layers: {best_hps.get('num_conv_layers')}")
for i in range(best_hps.get('num_conv_layers')):
    print(f"Filters in Conv Layer {i}: {best_hps.get(f'filters_{i}')}")
print(f"Dense Neurons: {best_hps.get('dense_neurons')}")
print(f"Dropout Rate: {best_hps.get('dropout_rate')}")
print(f"Learning Rate: {best_hps.get('learning_rate')}")
print(f"Best Validation Accuracy: {best_val_accuracy:.4f}")
# Out:
# Trial 72 Complete [00h 01m 46s]
# val_accuracy: 0.771399974822998
#
# Best val_accuracy So Far: 0.7815999984741211
# Total elapsed time: 01h 08m 52s
#
# Search: Running Trial #73
#
# Value             |Best Value So Far |Hyperparameter
# 4                 |4                 |num_conv_layers
# 256               |32                |filters_0
# 192               |224               |filters_1
# 128               |160               |filters_2
# 160               |64                |filters_3
# 64                |224               |filters_4
# 512               |1536              |dense_neurons
# 0.3               |0                 |dropout_rate
# 0.0028109         |0.0041138         |learning_rate
# 30                |30                |tuner/epochs
# 10                |10                |tuner/initial_epoch
# 2                 |3                 |tuner/bracket
# 2                 |3                 |tuner/round
# 0070              |0046              |tuner/trial_id

# %%
# Out:
# === Best Overall Hyperparameters ===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2c66b188efde> in <cell line: 0>()
#       1 # Print the best overall hyperparameters
#       2 print("\n=== Best Overall Hyperparameters ===")
# ----> 3 print(f"Best Batch Size: {best_batch_size}")
#       4 print(f"Number of Convolutional Layers: {best_hps.get('num_conv_layers')}")
#       5 for i in range(best_hps.get('num_conv_layers')):
#
# NameError: name 'best_batch_size' is not defined
