# %%
# import pandas as pd
import numpy as np
import os
import tensorflow as tf
import cv2
import keras
from keras.layers import Dense,Input, InputLayer, Flatten
from keras.models import Sequential, Model, load_model
from  matplotlib import pyplot as plt
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix,f1_score

# %%
#View some samples of the dataset
import random
plt.figure(figsize=(20,20))
folder=r'flowers/daisy'
for i in range(5):
    file = random.choice(os.listdir(folder))
    image_path= os.path.join(folder, file)
    img=mpimg.imread(image_path)
    ax=plt.subplot(1,5,i+1)
    ax.title.set_text(file)
    plt.imshow(img)

# %%
def load_and_preprocess_data(data_dir, image_size):
    images = []
    labels = []

    # Iterate through each folder (each class of flowers)
    for class_name in os.listdir(data_dir):
        class_dir = os.path.join(data_dir, class_name)

        # Iterate through each image in the class folder
        for image_name in os.listdir(class_dir):
            image_path = os.path.join(class_dir, image_name)

            # Read image and resize
            image = cv2.imread(image_path) #reads in BGR format
            #To read an image in grayscale 
            #image = cv2.imread(image_path,cv2.IMREAD_GRAYSCALE)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            image = cv2.resize(image, image_size)

            # Normalize pixel values to [0, 1]
            image = image.astype('float32') / 255.0

            # Append to the lists
            images.append(image)
            labels.append(class_name)

    # Convert lists to numpy arrays
    images = np.array(images)
    labels = np.array(labels)

    return images, labels

# %%
dataset_dir = "flowers"

# %%
image_size = (128, 128)

images, labels = load_and_preprocess_data(dataset_dir, image_size)

# %%
images
# Out:
# array([[[[0.5372549 , 0.5372549 , 0.5294118 ],
#          [0.5686275 , 0.5686275 , 0.5686275 ],
#          [0.5803922 , 0.5803922 , 0.58431375],
#          ...,
#          [0.6       , 0.6       , 0.5921569 ],
#          [0.6039216 , 0.6039216 , 0.59607846],
#          [0.6039216 , 0.6039216 , 0.6039216 ]],
#
#         [[0.5294118 , 0.5294118 , 0.52156866],
#          [0.5647059 , 0.5647059 , 0.56078434],
#          [0.5764706 , 0.5764706 , 0.5764706 ],
#          ...,
#          [0.6039216 , 0.6039216 , 0.59607846],
#          [0.6       , 0.6       , 0.5921569 ],
#          [0.5921569 , 0.5921569 , 0.5921569 ]],
#
#         [[0.5254902 , 0.52156866, 0.5058824 ],
#          [0.5568628 , 0.5529412 , 0.54509807],
#          [0.57254905, 0.5686275 , 0.56078434],
#          ...,
#          [0.6117647 , 0.6117647 , 0.60784316],
#          [0.59607846, 0.59607846, 0.5882353 ],
#          [0.5803922 , 0.5803922 , 0.5803922 ]],
#
#         ...,
#
#         [[0.16862746, 0.18039216, 0.09803922],
#          [0.16862746, 0.18039216, 0.09803922],
#          [0.16862746, 0.18039216, 0.09803922],
#          ...,
#          [0.5058824 , 0.49019608, 0.4862745 ],
#          [0.5019608 , 0.4862745 , 0.48235294],
#          [0.50980395, 0.49411765, 0.49019608]],
#
#         [[0.17254902, 0.18431373, 0.10196079],
#          [0.17254902, 0.18431373, 0.10196079],
#          [0.1764706 , 0.1882353 , 0.10588235],
#          ...,
#          [0.5176471 , 0.5019608 , 0.49803922],
#          [0.50980395, 0.49411765, 0.49019608],
#          [0.50980395, 0.49411765, 0.49019608]],
#
#         [[0.17254902, 0.18431373, 0.10196079],
#          [0.17254902, 0.18431373, 0.10196079],
#          [0.1764706 , 0.1882353 , 0.10588235],
#          ...,
#          [0.52156866, 0.5058824 , 0.5019608 ],
#          [0.5137255 , 0.49803922, 0.49411765],
#          [0.5137255 , 0.49803922, 0.49411765]]],
#
#
#        [[[0.84705883, 0.8509804 , 0.8784314 ],
#          [0.827451  , 0.827451  , 0.8627451 ],
#          [0.84705883, 0.85490197, 0.8862745 ],
#          ...,
#          [0.05490196, 0.04705882, 0.07450981],
#          [0.03137255, 0.04313726, 0.05490196],
#          [0.03137255, 0.02745098, 0.04705882]],
#
#         [[0.84705883, 0.84705883, 0.8784314 ],
#          [0.87058824, 0.88235295, 0.9098039 ],
#          [0.84313726, 0.85490197, 0.88235295],
#          ...,
#          [0.05098039, 0.04313726, 0.05098039],
#          [0.03137255, 0.02745098, 0.04313726],
#          [0.02352941, 0.02745098, 0.04313726]],
#
#         [[0.8862745 , 0.8980392 , 0.92941177],
#          [0.8745098 , 0.9019608 , 0.92156863],
#          [0.85490197, 0.8666667 , 0.8862745 ],
#          ...,
#          [0.04313726, 0.05098039, 0.05882353],
#          [0.03529412, 0.03529412, 0.04705882],
#          [0.01960784, 0.01568628, 0.03529412]],
#
#         ...,
#
#         [[0.6745098 , 0.6784314 , 0.7019608 ],
#          [0.7058824 , 0.69803923, 0.7176471 ],
#          [0.7176471 , 0.7294118 , 0.7490196 ],
#          ...,
#          [0.57254905, 0.5529412 , 0.4862745 ],
#          [0.67058825, 0.654902  , 0.6039216 ],
#          [0.7176471 , 0.68235296, 0.6509804 ]],
#
#         [[0.8039216 , 0.8156863 , 0.8352941 ],
#          [0.84313726, 0.8666667 , 0.88235295],
#          [0.87058824, 0.8901961 , 0.9137255 ],
#          ...,
#          [0.5882353 , 0.5568628 , 0.48235294],
#          [0.68235296, 0.6509804 , 0.6039216 ],
#          [0.7137255 , 0.6745098 , 0.6431373 ]],
#
#         [[0.8980392 , 0.9019608 , 0.9254902 ],
#          [0.8862745 , 0.9019608 , 0.92941177],
#          [0.89411765, 0.9098039 , 0.93333334],
#          ...,
#          [0.59607846, 0.57254905, 0.49411765],
#          [0.6862745 , 0.654902  , 0.59607846],
#          [0.7058824 , 0.65882355, 0.6313726 ]]],
#
#
#        [[[0.5137255 , 0.49803922, 0.4509804 ],
#          [0.4745098 , 0.47843137, 0.42745098],
#          [0.41960785, 0.4       , 0.3764706 ],
#          ...,
#          [0.61960787, 0.6392157 , 0.5529412 ],
#          [0.65882355, 0.67058825, 0.57254905],
#          [0.5647059 , 0.6039216 , 0.5019608 ]],
#
#         [[0.47843137, 0.4745098 , 0.44313726],
#          [0.4       , 0.4       , 0.37254903],
#          [0.36078432, 0.32156864, 0.34117648],
#          ...,
#          [0.54901963, 0.57254905, 0.5176471 ],
#          [0.5686275 , 0.58431375, 0.5176471 ],
#          [0.50980395, 0.54901963, 0.48235294]],
#
#         [[0.40784314, 0.40784314, 0.40392157],
#          [0.35686275, 0.3372549 , 0.35686275],
#          [0.28235295, 0.23137255, 0.29411766],
#          ...,
#          [0.46666667, 0.49411765, 0.43137255],
#          [0.4745098 , 0.49803922, 0.43137255],
#          [0.4509804 , 0.49019608, 0.42745098]],
#
#         ...,
#
#         [[0.10980392, 0.04705882, 0.16078432],
#          [0.10980392, 0.04705882, 0.16078432],
#          [0.09803922, 0.03529412, 0.14901961],
#          ...,
#          [0.1882353 , 0.09019608, 0.31764707],
#          [0.18431373, 0.08235294, 0.31764707],
#          [0.19215687, 0.07843138, 0.32156864]],
#
#         [[0.10588235, 0.04313726, 0.15686275],
#          [0.10588235, 0.04313726, 0.15686275],
#          [0.10196079, 0.03921569, 0.15294118],
#          ...,
#          [0.19607843, 0.08627451, 0.31764707],
#          [0.20784314, 0.09803922, 0.3372549 ],
#          [0.20784314, 0.09803922, 0.34117648]],
#
#         [[0.09411765, 0.03137255, 0.14901961],
#          [0.09411765, 0.03529412, 0.14901961],
#          [0.10196079, 0.03921569, 0.15294118],
#          ...,
#          [0.19607843, 0.07843138, 0.3137255 ],
#          [0.20784314, 0.09803922, 0.3372549 ],
#          [0.19215687, 0.08627451, 0.3254902 ]]],
#
#
#        ...,
#
#
#        [[[0.3529412 , 0.34509805, 0.22745098],
#          [0.43529412, 0.4392157 , 0.29411766],
#          [0.2509804 , 0.2627451 , 0.25882354],
#          ...,
#          [0.4       , 0.5411765 , 0.6666667 ],
#          [0.38039216, 0.5176471 , 0.62352943],
#          [0.41568628, 0.5882353 , 0.70980394]],
#
#         [[0.4       , 0.4       , 0.27450982],
#          [0.3254902 , 0.3254902 , 0.27058825],
#          [0.26666668, 0.2784314 , 0.25490198],
#          ...,
#          [0.42745098, 0.5568628 , 0.69411767],
#          [0.42745098, 0.5764706 , 0.7372549 ],
#          [0.39607844, 0.5137255 , 0.46666667]],
#
#         [[0.38039216, 0.38431373, 0.29803923],
#          [0.1882353 , 0.1882353 , 0.18039216],
#          [0.33333334, 0.34117648, 0.2901961 ],
#          ...,
#          [0.39607844, 0.52156866, 0.7176471 ],
#          [0.43529412, 0.6156863 , 0.75686276],
#          [0.43137255, 0.4745098 , 0.44313726]],
#
#         ...,
#
#         [[0.50980395, 0.4627451 , 0.3372549 ],
#          [0.5921569 , 0.54509807, 0.41960785],
#          [0.5529412 , 0.5058824 , 0.38039216],
#          ...,
#          [0.29803923, 0.3882353 , 0.21960784],
#          [0.3137255 , 0.39607844, 0.23529412],
#          [0.2784314 , 0.3764706 , 0.21960784]],
#
#         [[0.5176471 , 0.48235294, 0.34509805],
#          [0.4509804 , 0.42745098, 0.28627452],
#          [0.53333336, 0.49803922, 0.3647059 ],
#          ...,
#          [0.21568628, 0.30588236, 0.13725491],
#          [0.2627451 , 0.3372549 , 0.18039216],
#          [0.26666668, 0.3529412 , 0.19215687]],
#
#         [[0.47843137, 0.42745098, 0.3019608 ],
#          [0.47843137, 0.44705883, 0.30588236],
#          [0.5372549 , 0.49411765, 0.34509805],
#          ...,
#          [0.28627452, 0.36862746, 0.1882353 ],
#          [0.3019608 , 0.36862746, 0.20392157],
#          [0.2627451 , 0.32941177, 0.16862746]]],
#
#
#        [[[0.627451  , 0.6313726 , 0.6392157 ],
#          [0.6392157 , 0.6509804 , 0.64705884],
#          [0.5764706 , 0.54901963, 0.5686275 ],
#          ...,
#          [0.7294118 , 0.73333335, 0.67058825],
#          [0.83137256, 0.8784314 , 0.75686276],
#          [0.7921569 , 0.8117647 , 0.7529412 ]],
#
#         [[0.84705883, 0.75686276, 0.73333335],
#          [0.6431373 , 0.61960787, 0.5764706 ],
#          [0.9137255 , 0.93333334, 0.92941177],
#          ...,
#          [0.8156863 , 0.80784315, 0.74509805],
#          [0.75686276, 0.72156864, 0.60784316],
#          [0.67058825, 0.73333335, 0.7372549 ]],
#
#         [[0.89411765, 0.78039217, 0.57254905],
#          [0.9607843 , 0.93333334, 0.8666667 ],
#          [0.94509804, 0.9372549 , 0.9372549 ],
#          ...,
#          [0.5764706 , 0.6039216 , 0.47058824],
#          [0.60784316, 0.6509804 , 0.5764706 ],
#          [0.56078434, 0.6509804 , 0.52156866]],
#
#         ...,
#
#         [[0.01568628, 0.01568628, 0.01176471],
#          [0.11372549, 0.21568628, 0.19607843],
#          [0.19215687, 0.26666668, 0.23529412],
#          ...,
#          [0.05098039, 0.09803922, 0.05882353],
#          [0.07843138, 0.1254902 , 0.04705882],
#          [0.02745098, 0.03921569, 0.01568628]],
#
#         [[0.01960784, 0.04705882, 0.02352941],
#          [0.10980392, 0.22745098, 0.23137255],
#          [0.10588235, 0.18039216, 0.13333334],
#          ...,
#          [0.07450981, 0.11764706, 0.06666667],
#          [0.13725491, 0.16078432, 0.03921569],
#          [0.20784314, 0.1882353 , 0.06666667]],
#
#         [[0.04313726, 0.07843138, 0.04705882],
#          [0.14509805, 0.21960784, 0.22745098],
#          [0.03137255, 0.07058824, 0.03137255],
#          ...,
#          [0.06666667, 0.10980392, 0.04705882],
#          [0.1882353 , 0.1882353 , 0.02745098],
#          [0.3529412 , 0.3019608 , 0.05098039]]],
#
#
#        [[[0.26666668, 0.2509804 , 0.2509804 ],
#          [0.25882354, 0.25882354, 0.24313726],
#          [0.32941177, 0.30588236, 0.2901961 ],
#          ...,
#          [0.39607844, 0.5137255 , 0.5294118 ],
#          [0.45882353, 0.35686275, 0.44705883],
#          [0.32941177, 0.38039216, 0.4       ]],
#
#         [[0.16862746, 0.1764706 , 0.16862746],
#          [0.1764706 , 0.14901961, 0.1254902 ],
#          [0.27450982, 0.23529412, 0.23529412],
#          ...,
#          [0.49803922, 0.6       , 0.6313726 ],
#          [0.38039216, 0.49019608, 0.50980395],
#          [0.38039216, 0.48235294, 0.5019608 ]],
#
#         [[0.17254902, 0.1882353 , 0.10196079],
#          [0.16862746, 0.12941177, 0.1254902 ],
#          [0.17254902, 0.17254902, 0.17254902],
#          ...,
#          [0.5254902 , 0.6784314 , 0.69803923],
#          [0.5803922 , 0.5019608 , 0.5921569 ],
#          [0.3372549 , 0.3647059 , 0.39215687]],
#
#         ...,
#
#         [[0.4745098 , 0.2509804 , 0.01176471],
#          [0.49019608, 0.30980393, 0.01960784],
#          [0.1254902 , 0.16862746, 0.01176471],
#          ...,
#          [0.14117648, 0.23529412, 0.07843138],
#          [0.26666668, 0.35686275, 0.00784314],
#          [0.16078432, 0.20392157, 0.01568628]],
#
#         [[0.39215687, 0.25490198, 0.        ],
#          [0.3529412 , 0.21960784, 0.00784314],
#          [0.00784314, 0.00392157, 0.02745098],
#          ...,
#          [0.19215687, 0.29411766, 0.10196079],
#          [0.2509804 , 0.29803923, 0.        ],
#          [0.14117648, 0.20392157, 0.01568628]],
#
#         [[0.1764706 , 0.13333334, 0.00784314],
#          [0.13725491, 0.10196079, 0.        ],
#          [0.30588236, 0.34509805, 0.1254902 ],
#          ...,
#          [0.24705882, 0.32941177, 0.15294118],
#          [0.21960784, 0.24313726, 0.00392157],
#          [0.2       , 0.28235295, 0.05490196]]]], dtype=float32)

# %%
from sklearn.preprocessing import LabelEncoder
# Convert class labels to one-hot encoded vectors
label_encoder = LabelEncoder()
encoded_class_names = label_encoder.fit_transform(labels)

# %%
encoded_class_names
# Out:
# array([0, 0, 0, ..., 4, 4, 4], dtype=int64)

# %%
labels
# Out:
# array(['daisy', 'daisy', 'daisy', ..., 'tulip', 'tulip', 'tulip'],
#       dtype='<U9')

# %%
from sklearn.model_selection import train_test_split


# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(images, encoded_class_names, test_size=0.33, random_state=42)

y_train = np.array(y_train)
y_test = np.array(y_test)
X_train = np.array(X_train)
X_test = np.array(X_test)

# Check the shapes of the datasets
print("Train images shape:", X_train.shape)
print("Train labels shape:", X_test.shape)
print("Validation images shape:", y_train.shape)
print("Validation labels shape:", y_test.shape)
# Out:
# Train images shape: (2892, 128, 128, 3)
# Train labels shape: (1425, 128, 128, 3)
# Validation images shape: (2892,)
# Validation labels shape: (1425,)

# %%
y_train
# Out:
# array([0, 0, 3, ..., 3, 4, 1], dtype=int64)

# %%
model = keras.Sequential([
    keras.layers.Conv2D(128, (3, 3), input_shape=X_train.shape[1:]),
    keras.layers.LeakyReLU(alpha=0.02),
    
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.Dropout(0.25),

    keras.layers.Conv2D(128, (3, 3)),
    keras.layers.LeakyReLU(alpha=0.02),
    
    keras.layers.MaxPooling2D(pool_size=(2, 2)),
    keras.layers.Dropout(0.25),

    keras.layers.GlobalMaxPooling2D(),
    
    keras.layers.Dense(512),
    keras.layers.LeakyReLU(alpha=0.02),
    keras.layers.Dropout(0.5),

    keras.layers.Dense(10),
    keras.layers.Activation('softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# c:\Users\larai\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\larai\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 128)  │         3,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 126, 126, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 63, 63, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 61, 61, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 30, 30, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling2d            │ (None, 128)            │             0 │
# │ (GlobalMaxPooling2D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         5,130 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 10)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 222,346 (868.54 KB)
#  Trainable params: 222,346 (868.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
initial_lr = 0.0001
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_lr, decay_steps=10000, decay_rate=0.9
)
optimizer = Adam(learning_rate=lr_schedule)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5)

history = model.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.2642 - loss: 1.6953 - val_accuracy: 0.4870 - val_loss: 1.2901
# Epoch 2/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.4707 - loss: 1.1939 - val_accuracy: 0.5682 - val_loss: 1.0761
# Epoch 3/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 100s 1s/step - accuracy: 0.5690 - loss: 1.0360 - val_accuracy: 0.6114 - val_loss: 0.9980
# Epoch 4/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 97s 1s/step - accuracy: 0.6192 - loss: 0.9486 - val_accuracy: 0.6149 - val_loss: 0.9820
# Epoch 5/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 95s 1s/step - accuracy: 0.6294 - loss: 0.9166 - val_accuracy: 0.6269 - val_loss: 0.9081
# Epoch 6/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 103s 1s/step - accuracy: 0.6751 - loss: 0.8685 - val_accuracy: 0.7064 - val_loss: 0.8052
# Epoch 7/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 101s 1s/step - accuracy: 0.7015 - loss: 0.7859 - val_accuracy: 0.7047 - val_loss: 0.7765
# Epoch 8/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 101s 1s/step - accuracy: 0.7181 - loss: 0.7223 - val_accuracy: 0.6528 - val_loss: 0.8321
# Epoch 9/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 108s 1s/step - accuracy: 0.7157 - loss: 0.7189 - val_accuracy: 0.7271 - val_loss: 0.7710
# Epoch 10/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 100s 1s/step - accuracy: 0.7365 - loss: 0.6875 - val_accuracy: 0.7358 - val_loss: 0.7474
# Epoch 11/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 100s 1s/step - accuracy: 0.7417 - loss: 0.6691 - val_accuracy: 0.7237 - val_loss: 0.7790
# Epoch 12/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 100s 1s/step - accuracy: 0.7389 - loss: 0.6795 - val_accuracy: 0.7254 - val_loss: 0.7239
# Epoch 13/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 100s 1s/step - accuracy: 0.7657 - loss: 0.6194 - val_accuracy: 0.7617 - val_loss: 0.6858
# Epoch 14/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 102s 1s/step - accuracy: 0.7740 - loss: 0.6000 - val_accuracy: 0.7116 - val_loss: 0.7260
# Epoch 15/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 100s 1s/step - accuracy: 0.7888 - loss: 0.5693 - val_accuracy: 0.7306 - val_loss: 0.7060
# Epoch 16/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7936 - loss: 0.5263 - val_accuracy: 0.7219 - val_loss: 0.7148
# Epoch 17/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.8047 - loss: 0.5060 - val_accuracy: 0.7617 - val_loss: 0.6564
# Epoch 18/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.8003 - loss: 0.5160 - val_accuracy: 0.7392 - val_loss: 0.7084
# Epoch 19/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.7992 - loss: 0.5333 - val_accuracy: 0.7547 - val_loss: 0.6444
# Epoch 20/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - accuracy: 0.8205 - loss: 0.4457 - val_accuracy: 0.7547 - val_loss: 0.6398
# Epoch 21/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.8258 - loss: 0.4513 - val_accuracy: 0.7617 - val_loss: 0.6404
# Epoch 22/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.8358 - loss: 0.4362 - val_accuracy: 0.7651 - val_loss: 0.6294
# Epoch 23/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.8465 - loss: 0.4185 - val_accuracy: 0.7720 - val_loss: 0.6243
# Epoch 24/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.8650 - loss: 0.3819 - val_accuracy: 0.7461 - val_loss: 0.6141
# Epoch 25/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.8610 - loss: 0.3654 - val_accuracy: 0.7444 - val_loss: 0.6399
# Epoch 26/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.8698 - loss: 0.3481 - val_accuracy: 0.7755 - val_loss: 0.6460
# Epoch 27/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.8638 - loss: 0.3574 - val_accuracy: 0.7755 - val_loss: 0.6047
# Epoch 28/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.8795 - loss: 0.3227 - val_accuracy: 0.7824 - val_loss: 0.5973
# Epoch 29/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.8759 - loss: 0.3269 - val_accuracy: 0.7547 - val_loss: 0.6271
# Epoch 30/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.8937 - loss: 0.2866 - val_accuracy: 0.7530 - val_loss: 0.6888
# Epoch 31/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.8940 - loss: 0.2940 - val_accuracy: 0.7824 - val_loss: 0.5987
# Epoch 32/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 100s 1s/step - accuracy: 0.8970 - loss: 0.2676 - val_accuracy: 0.7340 - val_loss: 0.7327
# Epoch 33/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.8911 - loss: 0.2883 - val_accuracy: 0.7547 - val_loss: 0.6456
# Epoch 34/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - accuracy: 0.9024 - loss: 0.2528 - val_accuracy: 0.7651 - val_loss: 0.6621
# Epoch 35/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.8939 - loss: 0.2763 - val_accuracy: 0.7893 - val_loss: 0.5927
# Epoch 36/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9109 - loss: 0.2311 - val_accuracy: 0.7807 - val_loss: 0.6278
# Epoch 37/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.9125 - loss: 0.2348 - val_accuracy: 0.7651 - val_loss: 0.6724
# Epoch 38/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.8933 - loss: 0.2549 - val_accuracy: 0.7789 - val_loss: 0.6048
# Epoch 39/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.9220 - loss: 0.2104 - val_accuracy: 0.7461 - val_loss: 0.7355
# Epoch 40/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.9167 - loss: 0.2238 - val_accuracy: 0.7478 - val_loss: 0.6563
# Epoch 41/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9296 - loss: 0.1885 - val_accuracy: 0.7513 - val_loss: 0.6519
# Epoch 42/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9181 - loss: 0.2131 - val_accuracy: 0.7513 - val_loss: 0.6432
# Epoch 43/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9354 - loss: 0.1858 - val_accuracy: 0.7807 - val_loss: 0.6108
# Epoch 44/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.9349 - loss: 0.1806 - val_accuracy: 0.7530 - val_loss: 0.6816
# Epoch 45/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9347 - loss: 0.1846 - val_accuracy: 0.7634 - val_loss: 0.6721
# Epoch 46/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9228 - loss: 0.2203 - val_accuracy: 0.7634 - val_loss: 0.6678
# Epoch 47/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9438 - loss: 0.1462 - val_accuracy: 0.7530 - val_loss: 0.7616
# Epoch 48/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 88s 1s/step - accuracy: 0.9442 - loss: 0.1427 - val_accuracy: 0.7997 - val_loss: 0.6535
# Epoch 49/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.9535 - loss: 0.1277 - val_accuracy: 0.7789 - val_loss: 0.6750
# Epoch 50/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 91s 1s/step - accuracy: 0.9555 - loss: 0.1257 - val_accuracy: 0.7617 - val_loss: 0.7621

# %%
predicted_labels = model.predict(X_test)
predicted_labels = np.argmax(predicted_labels, axis=1)
#predicted_class_names = label_encoder.inverse_transform(predicted_labels)

f1 = f1_score(y_test, predicted_labels, average='macro')
report = classification_report(y_test, predicted_labels)

print("F1 Score:", f1)
print("Classification Report:")
print(report)
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 241ms/step
# F1 Score: 0.765791191181358
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.78      0.76       269
#            1       0.77      0.87      0.82       360
#            2       0.63      0.76      0.69       255
#            3       0.97      0.74      0.84       226
#            4       0.80      0.65      0.72       315
#
#     accuracy                           0.76      1425
#    macro avg       0.78      0.76      0.77      1425
# weighted avg       0.78      0.76      0.77      1425
